# %% [markdown]
# # About this notebook
# <p style="text-align: justify"> Here, you will learn the basic coding and data structures including numbers, strings, list, dictionaries and more. Some codes already done for demonstration. Some other codes, you will do as excercises.</p>
#
# ## Submission
# <p style="text-align: justify">After completing the practice codes and exercises, download the notebook (.pynb file) and submit the notebook  to MS Teams inbox in the class period</p>
# <p> 1.<b> You must submit your own code</b>. If similarity found negative marking will be given.</p>
# <p> 2. Modify the file name writing your ID at the beigining of the file name.</p>
# <p> 3. Other file format will not be accepted.</p>

# %% [markdown]
# # Number

# %%
# basic numeric operations
44 - 12
# Out:
# 32

# %%
# classic division returns a float
230/8
# Out:
# 28.75

# %%
# floor division discards the fractional part
# means output shows only int value.
223 // 5
# Out:
# 44

# %%
# assigin value to variable for later use
a = 9199 / 32
print(a)
# Out:
# 287.46875

# %%
# use the variable a for further operations
b = a*4
print(b)
# Out:
# 1149.875

# %%
a=5 ** 15
print(a)
# Out:
# 30517578125

# %% [markdown]
# <b>Exercise 1:</b> Assign values to some variables and perform different operations. Also print the results.

# %%
# code here
a = 22
b = 38
c = 5
d = a+b+c
print(d)
print(type(d))
d = a-b-c
print(d)
print(type(d))
d = (a+b)*c
print(d)
print(type(d))
d = b/(a-c)
print(d)
print(type(d))
# Out:
# 65
# <class 'int'>
# -21
# <class 'int'>
# 300
# <class 'int'>
# 2.235294117647059
# <class 'float'>

# %% [markdown]
# # Import Module
# <p style="text-align: justify"> Python code in one module gains access to the code in another module by the process of importing it. The import statement is the most common way of invoking the import machinery.</p>
#
# <p style="text-align: justify">Python’s standard library is very extensive, offering a wide range of facilities. The library contains built-in modules (written in C) that provide access to system functionality such as file I/O that would otherwise be inaccessible to Python programmers, as well as modules written in Python that provide standardized solutions for many problems that occur in everyday programming. Some of these modules are explicitly designed to encourage and enhance the portability of Python programs by abstracting away platform-specifics into platform-neutral APIs.</p>
#
# <b> Example:</b> Python has a built-in module that you can use for mathematical tasks. The math module has a set of methods and constants. The detail documentation can be found [here](https://docs.python.org/3/library/math.html).

# %%
# importing the math module
import math
# accessing the constant x from math
x = 440
print(math.sin(x))
print(math.tan(x))
# Out:
# 0.176105293265966
# 0.17890128141455483

# %%
# using the method sqrt from math/sqrt means rut.
math.sqrt(45)
# Out:
# 6.708203932499369

# %% [markdown]
# <b>Remember:</b> A cell always outputs the value of last variable. If you want to show other values use print. See the below cell for an example.

# %%
# here, a=22, and b=38;
print(111+222)
print(a*440)
print(a/b)
# Out:
# 333
# 9680
# 0.5789473684210527

# %% [markdown]
# <b>Exercise 2:</b> Import a module of your choice and show some operations.

# %%
import datetime

# Get the current date and time
now = datetime.datetime.now()
print(now)
# Out:
# 2023-10-23 16:46:06.678958

# %%
# ways to create Counter
from collections import Counter

# With sequence of items
print(Counter(['A','F','H','F','A','F','H','H','I',
			'M','A','I','F','A','F']))
# Out:
# Counter({'F': 5, 'A': 4, 'H': 3, 'I': 2, 'M': 1})

# %% [markdown]
# # Object types
# The basic object types are Numbers, Strings, Lists, Dictionaries, Tuples, Files and Other types (Sets, types, None, Booleans etc.)

# %%
x = 111.25
y = 32

# %%
# Checking the type of an object
print(type(x))
print(type(y))
# Out:
# <class 'float'>
# <class 'int'>

# %%
z = 'Fahim'
print(type(z))
# Out:
# <class 'str'>

# %%
x = 12.23
print(type(x))
# Out:
# <class 'float'>

# %%
x = 450
print(type(x))
# Out:
# <class 'int'>

# %%
x = 17
y = 90+x
print(y)
print(type(y))
# Out:
# 107
# <class 'int'>

# %% [markdown]
# # String

# %%
# assign value to a variable. The value can be qouted using '' or ""
n = "AL Faiaz"

# %%
# index
n[5]
# Out:
# 'i'

# %%
# negative index
n[-4]
# Out:
# 'a'

# %% [markdown]
# When to use ' ' or " " ?

# %% [markdown]
# string operations with * and +

# %%
'Rahman ' * 5
# Out:
# 'Rahman Rahman Rahman Rahman Rahman '

# %%
name = 'Faiaz'
name * 4
# Out:
# 'FaiazFaiazFaiazFaiaz'

# %%
'Faiaz ' + 'Rahman'
# Out:
# 'Faiaz Rahman'

# %%
name + ' Rahman'
# Out:
# 'Faiaz Rahman'

# %%
# slicing
name = 'Al Faiaz Rahman Fahim'
print(name[5:9])
print(name[6:])
print(name[:3])
print(name[-2:])
print(name[2:15:3])
print(name[-2: :-3])
# Out:
# iaz
# az Rahman Fahim
# Al
# im
#  i hn
# iFaazal

# %%
name[-10:-1]
# Out:
# 'hman Fahi'

# %%
#dir(name)
# importing os.path module
import os.path

path = 'Name: Fahim /Age: 22 /Address: Dhaka_Kuril/'

dirname = os.path.dirname(path)
print(dirname)
# Out:
# Name: Fahim /Age: 22 /Address: Dhaka_Kuril

# %% [markdown]
# Some examples of string methods

# %%
name = 'Al Faiaz Rahman Fahim'
sub = 'a'
name.count(sub)
# Out:
# 5

# %%
name = 'MD. AL FAIAZ RAHMAN FAHIM'
name.split()
# Out:
# ['MD.', 'AL', 'FAIAZ', 'RAHMAN', 'FAHIM']

# %%
name.isupper()
# Out:
# True

# %%
mystring = 'Hi..My Name Is Fahim\nThis Is My 8th Semester'
mystring.splitlines()
# Out:
# ['Hi..My Name Is Fahim', 'This Is My 8th Semester']

# %%
mystring = 'Hi..My Name Is Fahim\nThis Is My 8th Semester'
mystring.split()
# Out:
# ['Hi..My', 'Name', 'Is', 'Fahim', 'This', 'Is', 'My', '8th', 'Semester']

# %%
separator = '??'
mystrings = ['Al Faiaz', 'Rahman', 'Fahim', 'Khan']
separator.join(mystrings)
# Out:
# 'Al Faiaz??Rahman??Fahim??Khan'

# %%
#help(mystring.count)
string = 'Python is a very popular also a Higher Level programming language'

print('Number of p:', string.count('p'))
# Out:
# Number of p: 4

# %%
len(name)
# Out:
# 25

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(name.split)
# Out:
# Help on built-in function split:
#
# split(sep=None, maxsplit=-1) method of builtins.str instance
#     Return a list of the substrings in the string, using sep as the separator string.
#
#       sep
#         The separator used to split the string.
#
#         When set to None (the default value), will split on any whitespace
#         character (including \\n \\r \\t \\f and spaces) and will discard
#         empty strings from the result.
#       maxsplit
#         Maximum number of splits (starting from the left).
#         -1 (the default value) means no limit.
#
#     Note, str.split() is mainly useful for data that has been intentionally
#     delimited.  With natural text that includes punctuation, consider using
#     the regular expression module.

# %% [markdown]
# <b>Exercise 3:</b> Demonstrate some string operations. Also, show uses of some string methods.

# %%
# The price should be in fixed point, two-decimal format:

txt = "Price of this Book is only {price:.2f} Taka!"
print(txt.format(price = 4000))
# Out:
# Price of this Book is only 4000.00 Taka!

# %%
# Code here
s = "hello Student, Welcome to Artificial Intelligence Class."
# Capitalize/Upper case the first letter of this Sentence
a = s.capitalize()

print (a)
# Out:
# Hello student, welcome to artificial intelligence class.

# %% [markdown]
# # List
# <p style="text-align: justify">Python knows a number of compound data types, used to group together other values. The most versatile is the list, which can be written as a list of comma-separated values (items) between square brackets. Lists might contain items of different types, but usually the items all have the same type.</p>

# %%
squares = [2, 4, 6, 8, 10]
squares
# Out:
# [2, 4, 6, 8, 10]

# %%
data = [45, 'Sellsman', ['Sellsman', 90000] ,3.83, 'Kuril']

# %% [markdown]
# Like strings (and all other built-in sequence types), lists can be indexed and sliced:

# %%
data[-3][0]
# Out:
# 'Sellsman'

# %%
data[-2]
# Out:
# 3.83

# %%
data[1:4]
# Out:
# ['Sellsman', ['Sellsman', 90000], 3.83]

# %%
data[2]
# Out:
# ['Sellsman', 90000]

# %%
data[2][1]
# Out:
# 90000

# %%
len(data)
# Out:
# 5

# %%
data
# Out:
# [45, 'Sellsman', ['Sellsman', 90000], 3.83, 'Kuril']

# %% [markdown]
# Some list methods

# %%
data.append(100)
data.insert(2,222)
print(data)
# Out:
# [45, 'Sellsman', 222, ['Sellsman', 90000], 3.83, 'Kuril', 100]

# %%
data.remove(100)
data.pop()
print(data)
# Out:
# [45, 'Sellsman', 222, ['Sellsman', 90000], 3.83]

# %%
data.pop(1)
print(data)
# Out:
# [45, 222, ['Sellsman', 90000], 3.83]

# %%
dir(data)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
from types import LambdaType
#help(data.insert)
List = ['2', '3', '4']

List.insert(0, '1')
List.insert(4, '5')
List.insert(2, '6')


print(List)
# Out:
# ['1', '2', '6', '3', '4', '5']

# %% [markdown]
# Lists also support operations like concatenation

# %%
squares + data
# Out:
# [2, 4, 6, 8, 10, 45, 222, ['Sellsman', 90000], 3.83]

# %% [markdown]
# <b> Exercise 4:</b> Implement stack using list
# <p><b>Hints:</b> The list methods make it very easy to use a list as a stack, where the last element added is the first element retrieved (“last-in, first-out”). To add an item to the top of the stack, use append(). To retrieve an item from the top of the stack, use pop() without an explicit index</p>

# %%
# code here
# Stack implementation using list

stack = []
# append() function to push/append means add elements in last index.
stack.append('F')
stack.append('a')
stack.append('h')
stack.append('i')
stack.append('m')
stack.append('v')
stack.append('z')

print('Initial Stack: ')
print(stack)

# pop() function to pop
# LIFO order
print('\nPopped Elements from Stack: ')
print(stack.pop())
print(stack.pop())
print('\nAfter Popped the Stack is: ')
print(stack)
# Out:
# Initial Stack:
# ['F', 'a', 'h', 'i', 'm', 'v', 'z']
#
# Popped Elements from Stack:
# z
# v
#
# After Popped the Stack is:
# ['F', 'a', 'h', 'i', 'm']

# %% [markdown]
# <b> Exercise 5:</b> Implement queue using list
# <p><b>Hints:</b> It is also possible to use a list as a queue, where the first element added is the first element retrieved (“first-in, first-out”)</p>

# %%
# code here
# code here
# Queue implementation using list

queue = []
# append() function to push/append means add elements in last index.
queue.append('v')
queue.append('z')
queue.append('F')
queue.append('a')
queue.append('h')
queue.append('i')
queue.append('m')

print('Initial Queue: ')
print(queue)

# pop() function to pop
# FIFO order
print('\nPopped Elements from Queue: ')
print(queue.pop(0))
print(queue.pop(0))
print('\nAfter Popped the Queue is: ')
print(queue)
# Out:
# Initial Queue:
# ['v', 'z', 'F', 'a', 'h', 'i', 'm']
#
# Popped Elements from Queue:
# v
# z
#
# After Popped the Queue is:
# ['F', 'a', 'h', 'i', 'm']

# %% [markdown]
# # Dictionary
# <p style="text-align: justify">Dictionaries are sometimes found in other languages as “associative memories” or “associative arrays”. Unlike sequences, which are indexed by a range of numbers, dictionaries are indexed by keys, which can be any immutable type; strings and numbers can always be keys.</p>
#
# <p style="text-align: justify">It is best to think of a dictionary as a set of key: value pairs, with the requirement that the keys are unique (within one dictionary). A pair of braces creates an empty dictionary: {}. Placing a comma-separated list of key:value pairs within the braces adds initial key:value pairs to the dictionary; this is also the way dictionaries are written on output.</p>

# %%
tel = {'ALan': 4500, 'Walker': 70000}

# %%
tel['guido'] = 4400
tel
# Out:
# {'ALan': 4500, 'Walker': 70000, 'guido': 4400}

# %%
# Dictionary used as key
person = {'Age':22,'Name':['Faiaz','Rahman'], 'Salary':75000, 'Rating':4.6, 'Gender': 'Male'}

# %%
person['Salary']
# Out:
# 75000

# %%
len(person)
# Out:
# 5

# %%
person.keys()
# Out:
# dict_keys(['Age', 'Name', 'Salary', 'Rating', 'Gender'])

# %%
#person.has_key('Name')
'Name' in person.keys()
# Out:
# True

# %%
'Fahim' in person['Name']
# Out:
# False

# %%
#dir(person)
class Person:
  name = "alan"
  age = 30
  country = "Bangladesh"

print(dir(Person))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'age', 'country', 'name']

# %%
#dir(person)/ another way
class Person:
  name = "alan"
  age = 30
  country = "Bangladesh"

attributes = dir(person)

for attribute in attributes:
    print(attribute)
# Out:
# __class__
# __class_getitem__
# __contains__
# __delattr__
# __delitem__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getitem__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __ior__
# __iter__
# __le__
# __len__
# __lt__
# __ne__
# __new__
# __or__
# __reduce__
# __reduce_ex__
# __repr__
# __reversed__
# __ror__
# __setattr__
# __setitem__
# __sizeof__
# __str__
# __subclasshook__
# clear
# copy
# fromkeys
# get
# items
# keys
# pop
# popitem
# setdefault
# update
# values

# %% [markdown]
# <b> Exercise 6:</b> Define a dictionary to store the details of persons. Also, print some data from the dictionary.
#  <p><b>Hint:</b> You may require nesting dictionary, lists, string inside the dictionary.</p>

# %%
# Code here
class Person:
    def __init__(self,name, age, city, email):
          self.name = name
          self.age = age
          self.city = city
          self.email = email

# Create instances of the Person class to store details of persons
p1 = Person("Shaon", 23, "Dinajpur", "shaon@gmail.com")
p2 = Person("Fuad", 22, "Rangpur", "fuad@gmail.com")
p3 = Person("Turjo", 23, "Dhaka", "turjo@gmail.com")

# Access and print data for each person
print("Details of person 1:")
print("Name:", p1.name)
print("Age:", p1.age)
print("City:", p1.city)
print("Email:", p1.email)
print()

print("Details of person 2:")
print("Name:", p2.name)
print("Age:", p2.age)
print("City:", p2.city)
print("Email:", p2.email)
print()

print("Details of person 3:")
print("Name:", p3.name)
print("Age:", p3.age)
print("City:", p3.city)
print("Email:", p3.email)
# Out:
# Details of person 1:
# Name: Shaon
# Age: 23
# City: Dinajpur
# Email: shaon@gmail.com
#
# Details of person 2:
# Name: Fuad
# Age: 22
# City: Rangpur
# Email: fuad@gmail.com
#
# Details of person 3:
# Name: Turjo
# Age: 23
# City: Dhaka
# Email: turjo@gmail.com

# %% [markdown]
# # Tuples and Sets
# <b>Exercise 7: (Optional)</b> Use the content from [here](https://docs.python.org/3/tutorial/datastructures.html#tuples-and-sequences) to follow some examples on tuple and set.

# %%
# code from here
(1, 2, 3) + (4, 5, 6)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
('Hello World!',) * 4
# Out:
# ('Hello World!', 'Hello World!', 'Hello World!', 'Hello World!')

# %%
3 in (1, 2, 3)
# Out:
# True

# %%
4 in (1, 2, 3)
# Out:
# False
